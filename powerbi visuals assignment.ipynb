# %% [markdown]
#   Q1)Create a Card Visual to show Total Sales.
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q2)Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the
# highest sales?
#
# ![image.png](data:image/png;base64,...)
#
#
#
# -->Standard class generates the highest sales.

# %% [markdown]
# Q3)Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any
# noticeable seasonal pattern in sales?
#
# ![image.png](data:image/png;base64,...)
#
# The line chart shows the sales trend over time from 2011 to 2014. Sales generally increased over the years, with some fluctuations in between. Higher sales are visible towards the end of 2014, indicating business growth. Certain months show peaks and drops, suggesting seasonal variations in sales performance.

# %% [markdown]
# Q4)Create a Bar Chart to compare Sales by Category.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5) Create a Matrix Visual to display Sales by Month and Category and identify the month with the
# highest sales.
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# -->December recorded the highest total sales, indicating strong sales performance at the end of the year.

# %% [markdown]
# Q6)Create a Decomposition Tree for Sales Breakdown.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q7)Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers
# where high discounts resulted in negative profit?
#
#
# ![image.png](data:image/png;base64,...)
#
#
# -->The scatter chart compares Discount and Profit across different sub-categories. Most data points are concentrated in the middle range, forming the main cluster. However, a few points are spread far from the cluster at higher discount values, indicating outliers. These outliers show that high discounts resulted in lower or negative profit for certain sub-categories, suggesting that excessive discounts can lead to business losses.

# %% [markdown]
# Q8) Use a Funnel Chart to show the number of orders by Customer Segment.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q9)Use a Waterfall Chart to analyze how Profit changes by Category within the countries.
# ![image.png](data:image/png;base64,...)
#
# -->The waterfall chart shows how profit changes across different categories and countries. The Technology category contributed the highest positive profit. Countries like France and Italy increased the overall profit, while countries such as China, India, Germany, and Mexico showed decreases in profit. The Furniture category contributed the lowest profit, indicating weaker performance or losses. Overall, the chart highlights both positive and negative contributions affecting total profit.

# %% [markdown]
# Q10)Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month).
# ![image.png](data:image/png;base64,...)
#
#
# -->The chart shows the relationship between Sales and Profit across different months. Sales and profit generally increase toward the end of the year, with November and December showing the highest performance. Although higher sales often resulted in higher profit, some months showed fluctuations where profit did not increase proportionally with sales. Overall, the chart indicates a positive sales and profit trend over time.
